# %% [markdown]
# # Another Model / First experiment

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
import keras
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.utils import to_categorical
import numpy as np
from sklearn.metrics import confusion_matrix, f1_score
from sklearn.metrics import ConfusionMatrixDisplay

from keras.optimizers import SGD

# Load the data
data_1 = pd.read_csv('../EEG_mouse_data_1.csv')
data_2 = pd.read_csv('../EEG_mouse_data_2.csv')
data = pd.concat([data_1, data_2])

# Preprocess the data
features = data.columns[1:26]  # Select 25 features
X = data[features].values
y = data['state'].values  # Target variable

# Group 'n-rem' and 'rem' into 'asleep'
y = data['state'].replace(['n', 'r'], 'asleep').values


# Convert labels to integer values
encoder = LabelEncoder()
y = encoder.fit_transform(y)

# Convert integer labels to categorical
y = to_categorical(y)

# Define the MLP model
model = Sequential()
model.add(Input(shape=(25,))) # Input layer with 25 features
model.add(Dense(400, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(y.shape[1], activation='sigmoid'))  # Number of neurons equals number of classes

# Define your learning rate
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.1,
    decay_steps=10000,
    decay_rate=0.3)

# Pass the learning rate to the optimizer
sgd = SGD(learning_rate=lr_schedule, momentum=0.5)

model.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])

# Use 3-fold cross-validation
kf = KFold(n_splits=3, shuffle=True)
for train_index, val_index in kf.split(X):
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # Normalize the data
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)  # Fit and transform the training data
    X_val = scaler.transform(X_val)  # Transform the validation data

    # Train the model
    history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=30, batch_size=32)

    # Plot training and validation loss
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Losses')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

    # Evaluate the model
    y_pred = model.predict(X_val)
    
    print('Confusion Matrix:\n')
    # Compute confusion matrix
    cm = confusion_matrix(y_val.argmax(axis=1), y_pred.argmax(axis=1))

    # Create ConfusionMatrixDisplay instance
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.classes_)

    # Plot confusion matrix with black text
    disp.plot(cmap='binary', colorbar=False, values_format='d')
    plt.show()
        
    confusion_matrix(y_val.argmax(axis=1), y_pred.argmax(axis=1))
    
    f1_scores_per_class = f1_score(y_val.argmax(axis=1), y_pred.argmax(axis=1), average=None)
    f1_score_micro = f1_score(y_val.argmax(axis=1), y_pred.argmax(axis=1), average='micro')

    print('F1 Score per class: ', f1_scores_per_class)
    print('Micro F1 Score: ', f1_score_micro)
    
# Save the model's predictions on the test set
test_data = pd.read_csv('../EEG_mouse_data_test.csv')
X_test = test_data[features].values  # Use the same features as the training data
X_test = scaler.transform(X_test)  # Use the same scaler fitted on the last training fold
test_predictions = model.predict(X_test)

model.summary()
# Out:
# Epoch 1/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 935us/step - accuracy: 0.8617 - loss: 0.1070 - val_accuracy: 0.8896 - val_loss: 0.0820
# Epoch 2/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 883us/step - accuracy: 0.8885 - loss: 0.0827 - val_accuracy: 0.8949 - val_loss: 0.0794
# Epoch 3/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 833us/step - accuracy: 0.8946 - loss: 0.0793 - val_accuracy: 0.8946 - val_loss: 0.0797
# Epoch 4/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 838us/step - accuracy: 0.8948 - loss: 0.0803 - val_accuracy: 0.8950 - val_loss: 0.0797
# Epoch 5/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 797us/step - accuracy: 0.8969 - loss: 0.0767 - val_accuracy: 0.8955 - val_loss: 0.0789
# Epoch 6/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 820us/step - accuracy: 0.9012 - loss: 0.0757 - val_accuracy: 0.8938 - val_loss: 0.0796
# Epoch 7/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 817us/step - accuracy: 0.9020 - loss: 0.0740 - val_accuracy: 0.8943 - val_loss: 0.0796
# Epoch 8/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 835us/step - accuracy: 0.9060 - loss: 0.0730 - val_accuracy: 0.8952 - val_loss: 0.0790
# Epoch 9/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 862us/step - accuracy: 0.9067 - loss: 0.0715 - val_accuracy: 0.8938 - val_loss: 0.0794
# Epoch 10/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 953us/step - accuracy: 0.9098 - loss: 0.0701 - val_accuracy: 0.8958 - val_loss: 0.0790
# Epoch 11/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 860us/step - accuracy: 0.9095 - loss: 0.0702 - val_accuracy: 0.8963 - val_loss: 0.0790
# Epoch 12/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 852us/step - accuracy: 0.9134 - loss: 0.0685 - val_accuracy: 0.8942 - val_loss: 0.0793
# Epoch 13/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 825us/step - accuracy: 0.9126 - loss: 0.0687 - val_accuracy: 0.8933 - val_loss: 0.0794
# Epoch 14/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 821us/step - accuracy: 0.9154 - loss: 0.0672 - val_accuracy: 0.8955 - val_loss: 0.0794
# Epoch 15/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 811us/step - accuracy: 0.9146 - loss: 0.0669 - val_accuracy: 0.8941 - val_loss: 0.0795
# Epoch 16/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 867us/step - accuracy: 0.9147 - loss: 0.0681 - val_accuracy: 0.8925 - val_loss: 0.0798
# Epoch 17/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 820us/step - accuracy: 0.9183 - loss: 0.0659 - val_accuracy: 0.8952 - val_loss: 0.0800
# Epoch 18/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 917us/step - accuracy: 0.9219 - loss: 0.0634 - val_accuracy: 0.8924 - val_loss: 0.0809
# Epoch 19/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 800us/step - accuracy: 0.9219 - loss: 0.0626 - val_accuracy: 0.8919 - val_loss: 0.0804
# Epoch 20/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 823us/step - accuracy: 0.9257 - loss: 0.0606 - val_accuracy: 0.8927 - val_loss: 0.0801
# Epoch 21/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 801us/step - accuracy: 0.9241 - loss: 0.0617 - val_accuracy: 0.8938 - val_loss: 0.0805
# Epoch 22/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 790us/step - accuracy: 0.9274 - loss: 0.0601 - val_accuracy: 0.8933 - val_loss: 0.0802
# Epoch 23/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 860us/step - accuracy: 0.9269 - loss: 0.0605 - val_accuracy: 0.8933 - val_loss: 0.0806
# Epoch 24/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 828us/step - accuracy: 0.9273 - loss: 0.0607 - val_accuracy: 0.8931 - val_loss: 0.0809
# Epoch 25/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 817us/step - accuracy: 0.9304 - loss: 0.0583 - val_accuracy: 0.8914 - val_loss: 0.0813
# Epoch 26/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 865us/step - accuracy: 0.9323 - loss: 0.0575 - val_accuracy: 0.8923 - val_loss: 0.0808
# Epoch 27/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 801us/step - accuracy: 0.9295 - loss: 0.0596 - val_accuracy: 0.8940 - val_loss: 0.0806
# Epoch 28/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 813us/step - accuracy: 0.9312 - loss: 0.0585 - val_accuracy: 0.8921 - val_loss: 0.0808
# Epoch 29/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 812us/step - accuracy: 0.9333 - loss: 0.0571 - val_accuracy: 0.8922 - val_loss: 0.0810
# Epoch 30/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9320 - loss: 0.0577 - val_accuracy: 0.8926 - val_loss: 0.0807
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step
# Confusion Matrix:
# F1 Score per class:  [0.86086543 0.91253662]
# Micro F1 Score:  0.8925923206813009
# Epoch 1/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9124 - loss: 0.0699 - val_accuracy: 0.9314 - val_loss: 0.0577
# Epoch 2/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 919us/step - accuracy: 0.9181 - loss: 0.0664 - val_accuracy: 0.9318 - val_loss: 0.0577
# Epoch 3/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 889us/step - accuracy: 0.9130 - loss: 0.0691 - val_accuracy: 0.9299 - val_loss: 0.0582
# Epoch 4/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 840us/step - accuracy: 0.9198 - loss: 0.0653 - val_accuracy: 0.9300 - val_loss: 0.0583
# Epoch 5/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9188 - loss: 0.0659 - val_accuracy: 0.9289 - val_loss: 0.0589
# Epoch 6/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9211 - loss: 0.0648 - val_accuracy: 0.9289 - val_loss: 0.0586
# Epoch 7/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9198 - loss: 0.0661 - val_accuracy: 0.9289 - val_loss: 0.0588
# Epoch 8/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9189 - loss: 0.0658 - val_accuracy: 0.9284 - val_loss: 0.0591
# Epoch 9/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9195 - loss: 0.0641 - val_accuracy: 0.9290 - val_loss: 0.0591
# Epoch 10/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9188 - loss: 0.0647 - val_accuracy: 0.9283 - val_loss: 0.0592
# Epoch 11/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9205 - loss: 0.0646 - val_accuracy: 0.9274 - val_loss: 0.0594
# Epoch 12/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9196 - loss: 0.0650 - val_accuracy: 0.9272 - val_loss: 0.0596
# Epoch 13/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9208 - loss: 0.0632 - val_accuracy: 0.9275 - val_loss: 0.0596
# Epoch 14/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9228 - loss: 0.0631 - val_accuracy: 0.9275 - val_loss: 0.0596
# Epoch 15/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9216 - loss: 0.0650 - val_accuracy: 0.9274 - val_loss: 0.0596
# Epoch 16/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9227 - loss: 0.0630 - val_accuracy: 0.9267 - val_loss: 0.0597
# Epoch 17/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9230 - loss: 0.0635 - val_accuracy: 0.9272 - val_loss: 0.0597
# Epoch 18/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9235 - loss: 0.0618 - val_accuracy: 0.9272 - val_loss: 0.0597
# Epoch 19/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9226 - loss: 0.0633 - val_accuracy: 0.9268 - val_loss: 0.0598
# Epoch 20/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9228 - loss: 0.0636 - val_accuracy: 0.9273 - val_loss: 0.0598
# Epoch 21/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9225 - loss: 0.0637 - val_accuracy: 0.9271 - val_loss: 0.0598
# Epoch 22/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9210 - loss: 0.0648 - val_accuracy: 0.9265 - val_loss: 0.0600
# Epoch 23/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9213 - loss: 0.0631 - val_accuracy: 0.9268 - val_loss: 0.0599
# Epoch 24/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9249 - loss: 0.0624 - val_accuracy: 0.9265 - val_loss: 0.0599
# Epoch 25/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9226 - loss: 0.0632 - val_accuracy: 0.9262 - val_loss: 0.0600
# Epoch 26/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9215 - loss: 0.0636 - val_accuracy: 0.9266 - val_loss: 0.0599
# Epoch 27/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9248 - loss: 0.0617 - val_accuracy: 0.9264 - val_loss: 0.0600
# Epoch 28/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9234 - loss: 0.0636 - val_accuracy: 0.9265 - val_loss: 0.0600
# Epoch 29/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9217 - loss: 0.0649 - val_accuracy: 0.9262 - val_loss: 0.0600
# Epoch 30/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9248 - loss: 0.0609 - val_accuracy: 0.9266 - val_loss: 0.0600
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step
# Confusion Matrix:
# F1 Score per class:  [0.90597969 0.9397808 ]
# Micro F1 Score:  0.9265839512517436
# Epoch 1/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9183 - loss: 0.0652 - val_accuracy: 0.9383 - val_loss: 0.0543
# Epoch 2/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9167 - loss: 0.0657 - val_accuracy: 0.9382 - val_loss: 0.0544
# Epoch 3/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9211 - loss: 0.0637 - val_accuracy: 0.9381 - val_loss: 0.0544
# Epoch 4/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9171 - loss: 0.0664 - val_accuracy: 0.9378 - val_loss: 0.0545
# Epoch 5/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9192 - loss: 0.0647 - val_accuracy: 0.9378 - val_loss: 0.0545
# Epoch 6/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9160 - loss: 0.0661 - val_accuracy: 0.9377 - val_loss: 0.0545
# Epoch 7/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9206 - loss: 0.0638 - val_accuracy: 0.9377 - val_loss: 0.0545
# Epoch 8/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9176 - loss: 0.0656 - val_accuracy: 0.9376 - val_loss: 0.0546
# Epoch 9/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9172 - loss: 0.0659 - val_accuracy: 0.9376 - val_loss: 0.0546
# Epoch 10/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9179 - loss: 0.0656 - val_accuracy: 0.9377 - val_loss: 0.0546
# Epoch 11/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9188 - loss: 0.0656 - val_accuracy: 0.9376 - val_loss: 0.0546
# Epoch 12/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 35s 41ms/step - accuracy: 0.9171 - loss: 0.0661 - val_accuracy: 0.9374 - val_loss: 0.0546
# Epoch 13/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9213 - loss: 0.0643 - val_accuracy: 0.9374 - val_loss: 0.0547
# Epoch 14/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9204 - loss: 0.0642 - val_accuracy: 0.9374 - val_loss: 0.0547
# Epoch 15/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9162 - loss: 0.0662 - val_accuracy: 0.9374 - val_loss: 0.0547
# Epoch 16/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9182 - loss: 0.0662 - val_accuracy: 0.9374 - val_loss: 0.0547
# Epoch 17/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9208 - loss: 0.0636 - val_accuracy: 0.9374 - val_loss: 0.0547
# Epoch 18/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9166 - loss: 0.0661 - val_accuracy: 0.9374 - val_loss: 0.0547
# Epoch 19/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9188 - loss: 0.0646 - val_accuracy: 0.9374 - val_loss: 0.0547
# Epoch 20/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9190 - loss: 0.0650 - val_accuracy: 0.9374 - val_loss: 0.0547
# Epoch 21/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9203 - loss: 0.0643 - val_accuracy: 0.9375 - val_loss: 0.0547
# Epoch 22/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9154 - loss: 0.0677 - val_accuracy: 0.9374 - val_loss: 0.0547
# Epoch 23/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9176 - loss: 0.0659 - val_accuracy: 0.9374 - val_loss: 0.0547
# Epoch 24/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9183 - loss: 0.0649 - val_accuracy: 0.9374 - val_loss: 0.0547
# Epoch 25/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9218 - loss: 0.0643 - val_accuracy: 0.9374 - val_loss: 0.0547
# Epoch 26/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9170 - loss: 0.0663 - val_accuracy: 0.9374 - val_loss: 0.0547
# Epoch 27/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9196 - loss: 0.0657 - val_accuracy: 0.9374 - val_loss: 0.0547
# Epoch 28/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9197 - loss: 0.0645 - val_accuracy: 0.9374 - val_loss: 0.0547
# Epoch 29/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9215 - loss: 0.0627 - val_accuracy: 0.9373 - val_loss: 0.0547
# Epoch 30/30
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9172 - loss: 0.0659 - val_accuracy: 0.9373 - val_loss: 0.0547
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Confusion Matrix:
# F1 Score per class:  [0.92086731 0.94808511]
# Micro F1 Score:  0.937302694368989
# 2504/2504 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 400)            │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 200)            │        80,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 100)            │        20,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 2)              │           202 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 221,805 (866.43 KB)
#  Trainable params: 110,902 (433.21 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 110,903 (433.22 KB)
